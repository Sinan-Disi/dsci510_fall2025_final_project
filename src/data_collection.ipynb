# %%
# Collecting Rawg data by API 
# !pip install -q pandas requests python-dotenv

import os
import time
import random
import requests
import pandas as pd
from dotenv import load_dotenv

load_dotenv()  
API_KEY = os.getenv("RAWG_API_KEY")
if not API_KEY:
    raise RuntimeError(
        "RAWG_API_KEY not found. Create a .env file in your project root with:\n"
        "RAWG_API_KEY=your_key_here"
    )

games = []
target_per_bucket = 800  
buckets = [
    ("2000-01-01", "2004-12-31"),
    ("2005-01-01", "2009-12-31"),
    ("2010-01-01", "2014-12-31"),
    ("2015-01-01", "2019-12-31"),
    ("2020-01-01", "2025-12-31"),
]

print("Starting RAWG data collection (2000–2025)…\n")

session = requests.Session()
BASE = "https://api.rawg.io/api/games"

for start, end in buckets:
    print(f"Collecting for {start[:4]}–{end[:4]}…")
    collected = 0
    attempts = 0

    page_limit = 200 if int(start[:4]) < 2010 else 800

    while collected < target_per_bucket and attempts < 200:
        page = random.randint(1, page_limit)
        params = {
            "key": API_KEY,
            "page_size": 100,
            "page": page,
            "dates": f"{start},{end}",
        }

        try:
            r = session.get(BASE, params=params, timeout=20)
        except requests.RequestException:
            attempts += 1
            time.sleep(1)
            continue

        attempts += 1
        if r.status_code != 200:
            print(f"  Skipped page {page} (error {r.status_code})")
            time.sleep(1)
            continue

        data = r.json().get("results", [])
        if not data:
            time.sleep(0.5)
            continue

        for g in data:
            platforms = g.get("platforms") or []
            platform_names = ", ".join(
                p["platform"]["name"]
                for p in platforms
                if p and p.get("platform") and p["platform"].get("name")
            )

            genres_list = g.get("genres") or []
            genre_names = ", ".join(
                p.get("name", "")
                for p in genres_list
                if p and p.get("name")
            )

            games.append({
                "name": g.get("name"),
                "rating": g.get("rating"),
                "released": g.get("released"),
                "platforms": platform_names if platform_names else None,
                "genres": genre_names if genre_names else None,
            })

            collected += 1
            if collected >= target_per_bucket:
                break

        if collected % 40 == 0:
            print(f"  {collected} games collected so far for {start[:4]}–{end[:4]}")
        time.sleep(1)  

df = pd.DataFrame(games)
df["year"] = pd.to_datetime(df["released"], errors="coerce").dt.year

print("\nCollection complete.")
print("Total collected:", len(df))
print(df["year"].value_counts().sort_index())

os.makedirs("data", exist_ok=True)
out_path = "data/rawg_balanced_2000_2025.csv"
df.to_csv(out_path, index=False)
print("Saved dataset:", out_path)
# Out:
# Starting RAWG data collection (2000–2025)…
#
# Collecting for 2000–2004…
#   Skipped page 195 (error 404)
#   40 games collected so far for 2000–2004
#   Skipped page 188 (error 404)
#   80 games collected so far for 2000–2004
#   Skipped page 191 (error 404)
#   120 games collected so far for 2000–2004
#   160 games collected so far for 2000–2004
#   200 games collected so far for 2000–2004
#   Skipped page 182 (error 404)
#   240 games collected so far for 2000–2004
#   280 games collected so far for 2000–2004
#   320 games collected so far for 2000–2004
#   360 games collected so far for 2000–2004
#   Skipped page 194 (error 404)
#   400 games collected so far for 2000–2004
#   Skipped page 199 (error 404)
#   440 games collected so far for 2000–2004
#   Skipped page 144 (error 404)
#   480 games collected so far for 2000–2004
#   Skipped page 162 (error 404)
#   Skipped page 200 (error 404)
#   520 games collected so far for 2000–2004
#   560 games collected so far for 2000–2004
#   600 games collected so far for 2000–2004
#   Skipped page 194 (error 502)
#   Skipped page 27 (error 502)
#   Skipped page 170 (error 502)
#   Skipped page 72 (error 502)
#   Skipped page 173 (error 502)
#   Skipped page 110 (error 502)
#   Skipped page 193 (error 502)
#   Skipped page 37 (error 502)
#   Skipped page 17 (error 502)
#   640 games collected so far for 2000–2004
#   Skipped page 174 (error 404)
#   Skipped page 198 (error 404)
#   680 games collected so far for 2000–2004
#   720 games collected so far for 2000–2004
#   760 games collected so far for 2000–2004
#   800 games collected so far for 2000–2004
# Collecting for 2005–2009…
#   40 games collected so far for 2005–2009
#   80 games collected so far for 2005–2009
#   120 games collected so far for 2005–2009
#   160 games collected so far for 2005–2009
#   200 games collected so far for 2005–2009
#   240 games collected so far for 2005–2009
#   280 games collected so far for 2005–2009
#   320 games collected so far for 2005–2009
#   360 games collected so far for 2005–2009
#   400 games collected so far for 2005–2009
#   440 games collected so far for 2005–2009
#   480 games collected so far for 2005–2009
#   520 games collected so far for 2005–2009
#   560 games collected so far for 2005–2009
#   600 games collected so far for 2005–2009
#   640 games collected so far for 2005–2009
#   680 games collected so far for 2005–2009
#   720 games collected so far for 2005–2009
#   760 games collected so far for 2005–2009
#   800 games collected so far for 2005–2009
# Collecting for 2010–2014…
#   Skipped page 547 (error 404)
#   Skipped page 435 (error 404)
#   Skipped page 313 (error 404)
#   Skipped page 598 (error 404)
#   Skipped page 625 (error 404)
#   Skipped page 272 (error 404)
#   Skipped page 528 (error 404)
#   Skipped page 501 (error 404)
#   Skipped page 521 (error 404)
#   40 games collected so far for 2010–2014
#   Skipped page 362 (error 404)
#   Skipped page 320 (error 404)
#   80 games collected so far for 2010–2014
#   Skipped page 432 (error 404)
#   Skipped page 622 (error 404)
#   Skipped page 298 (error 404)
#   Skipped page 578 (error 404)
#   Skipped page 729 (error 404)
#   120 games collected so far for 2010–2014
#   Skipped page 762 (error 404)
#   160 games collected so far for 2010–2014
#   Skipped page 578 (error 404)
#   Skipped page 668 (error 404)
#   200 games collected so far for 2010–2014
#   Skipped page 413 (error 404)
#   240 games collected so far for 2010–2014
#   Skipped page 704 (error 404)
#   Skipped page 521 (error 404)
#   Skipped page 581 (error 404)
#   Skipped page 632 (error 404)
#   280 games collected so far for 2010–2014
#   320 games collected so far for 2010–2014
#   360 games collected so far for 2010–2014
#   Skipped page 630 (error 404)
#   Skipped page 611 (error 404)
#   Skipped page 379 (error 404)
#   Skipped page 637 (error 404)
#   Skipped page 507 (error 404)
#   Skipped page 739 (error 404)
#   Skipped page 291 (error 404)
#   Skipped page 706 (error 404)
#   Skipped page 475 (error 404)
#   400 games collected so far for 2010–2014
#   Skipped page 575 (error 404)
#   440 games collected so far for 2010–2014
#   Skipped page 276 (error 404)
#   Skipped page 519 (error 404)
#   Skipped page 736 (error 404)
#   Skipped page 554 (error 404)
#   Skipped page 318 (error 404)
#   Skipped page 769 (error 404)
#   480 games collected so far for 2010–2014
#   Skipped page 721 (error 404)
#   Skipped page 722 (error 404)
#   Skipped page 389 (error 404)
#   Skipped page 506 (error 404)
#   520 games collected so far for 2010–2014
#   560 games collected so far for 2010–2014
#   Skipped page 332 (error 404)
#   Skipped page 358 (error 404)
#   Skipped page 747 (error 404)
#   Skipped page 719 (error 404)
#   Skipped page 691 (error 404)
#   Skipped page 254 (error 404)
#   Skipped page 285 (error 404)
#   Skipped page 263 (error 404)
#   600 games collected so far for 2010–2014
#   Skipped page 486 (error 404)
#   Skipped page 388 (error 404)
#   640 games collected so far for 2010–2014
#   680 games collected so far for 2010–2014
#   720 games collected so far for 2010–2014
#   760 games collected so far for 2010–2014
#   800 games collected so far for 2010–2014
# Collecting for 2015–2019…
#   Skipped page 371 (error 404)
#   Skipped page 667 (error 404)
#   40 games collected so far for 2015–2019
#   80 games collected so far for 2015–2019
#   120 games collected so far for 2015–2019
#   Skipped page 614 (error 404)
#   160 games collected so far for 2015–2019
#   Skipped page 544 (error 404)
#   Skipped page 778 (error 404)
#   Skipped page 560 (error 404)
#   Skipped page 794 (error 404)
#   200 games collected so far for 2015–2019
#   Skipped page 724 (error 404)
#   240 games collected so far for 2015–2019
#   Skipped page 732 (error 404)
#   Skipped page 631 (error 404)
#   Skipped page 620 (error 404)
#   280 games collected so far for 2015–2019
#   320 games collected so far for 2015–2019
#   Skipped page 647 (error 404)
#   Skipped page 744 (error 404)
#   Skipped page 338 (error 404)
#   360 games collected so far for 2015–2019
#   Skipped page 467 (error 404)
#   Skipped page 314 (error 404)
#   400 games collected so far for 2015–2019
#   440 games collected so far for 2015–2019
#   Skipped page 601 (error 404)
#   480 games collected so far for 2015–2019
#   Skipped page 519 (error 404)
#   Skipped page 501 (error 404)
#   Skipped page 324 (error 404)
#   Skipped page 615 (error 404)
#   520 games collected so far for 2015–2019
#   560 games collected so far for 2015–2019
#   Skipped page 555 (error 404)
#   600 games collected so far for 2015–2019
#   Skipped page 699 (error 404)
#   640 games collected so far for 2015–2019
#   680 games collected so far for 2015–2019
#   720 games collected so far for 2015–2019
#   760 games collected so far for 2015–2019
#   800 games collected so far for 2015–2019
# Collecting for 2020–2025…
#   40 games collected so far for 2020–2025
#   80 games collected so far for 2020–2025
#   Skipped page 731 (error 404)
#   Skipped page 432 (error 404)
#   Skipped page 267 (error 404)
#   Skipped page 769 (error 404)
#   Skipped page 701 (error 404)
#   120 games collected so far for 2020–2025
#   Skipped page 459 (error 404)
#   Skipped page 693 (error 404)
#   160 games collected so far for 2020–2025
#   Skipped page 686 (error 404)
#   Skipped page 556 (error 404)
#   200 games collected so far for 2020–2025
#   Skipped page 621 (error 404)
#   Skipped page 571 (error 404)
#   Skipped page 597 (error 404)
#   Skipped page 298 (error 404)
#   Skipped page 761 (error 404)
#   Skipped page 310 (error 404)
#   240 games collected so far for 2020–2025
#   Skipped page 361 (error 404)
#   Skipped page 431 (error 404)
#   Skipped page 309 (error 404)
#   Skipped page 756 (error 404)
#   280 games collected so far for 2020–2025
#   320 games collected so far for 2020–2025
#   Skipped page 290 (error 404)
#   Skipped page 531 (error 404)
#   Skipped page 423 (error 404)
#   Skipped page 424 (error 404)
#   360 games collected so far for 2020–2025
#   Skipped page 491 (error 404)
#   Skipped page 571 (error 404)
#   Skipped page 785 (error 404)
#   Skipped page 325 (error 404)
#   Skipped page 473 (error 404)
#   Skipped page 727 (error 404)
#   Skipped page 345 (error 404)
#   Skipped page 294 (error 404)
#   Skipped page 641 (error 404)
#   400 games collected so far for 2020–2025
#   Skipped page 601 (error 404)
#   Skipped page 467 (error 404)
#   Skipped page 302 (error 404)
#   440 games collected so far for 2020–2025
#   Skipped page 616 (error 404)
#   Skipped page 798 (error 404)
#   Skipped page 639 (error 404)
#   Skipped page 463 (error 404)
#   Skipped page 620 (error 404)
#   480 games collected so far for 2020–2025
#   Skipped page 733 (error 404)
#   Skipped page 784 (error 404)
#   Skipped page 265 (error 404)
#   Skipped page 778 (error 404)
#   Skipped page 448 (error 404)
#   520 games collected so far for 2020–2025
#   560 games collected so far for 2020–2025
#   600 games collected so far for 2020–2025
#   640 games collected so far for 2020–2025
#   Skipped page 499 (error 404)
#   Skipped page 541 (error 404)
#   Skipped page 469 (error 404)
#   Skipped page 709 (error 404)
#   Skipped page 644 (error 404)
#   680 games collected so far for 2020–2025
#   Skipped page 268 (error 404)
#   720 games collected so far for 2020–2025
#   Skipped page 671 (error 404)
#   Skipped page 512 (error 404)
#   760 games collected so far for 2020–2025
#   Skipped page 477 (error 404)
#   Skipped page 272 (error 404)
#   Skipped page 708 (error 404)
#   Skipped page 347 (error 404)
#   Skipped page 562 (error 404)
#   Skipped page 453 (error 404)
#   Skipped page 761 (error 404)
#   800 games collected so far for 2020–2025
#
# Collection complete.
# Total collected: 4000
# year
# 2000    148
# 2001    170
# 2002    144
# 2003    172
# 2004    166
# 2005     94
# 2006    117
# 2007    149
# 2008    188
# 2009    252
# 2010    150
# 2011    145
# 2012    155
# 2013    144
# 2014    206
# 2015    166
# 2016    213
# 2017    215
# 2018    132
# 2019     74
# 2020    190
# 2021    198
# 2022    155
# 2023    132
# 2024     95
# 2025     30
# Name: count, dtype: int64
# Saved dataset: data/rawg_balanced_2000_2025.csv

# %%
#Collecting Raw Steam Data by API   & Collecting Raw Data Sales data by API
# !pip install -q kaggle

import os
import shutil
from kaggle import api
import pandas as pd

os.makedirs("data", exist_ok=True)

home = os.path.expanduser("~")
kaggle_dir = os.path.join(home, ".kaggle")
os.makedirs(kaggle_dir, exist_ok=True)

src_cfg = "kaggle.json"
dst_cfg = os.path.join(kaggle_dir, "kaggle.json")
if os.path.exists(src_cfg):
    shutil.copyfile(src_cfg, dst_cfg)
try:
    if os.name == "posix":
        os.chmod(dst_cfg, 0o600)
except Exception:
    pass

def fetch_kaggle_dataset(dataset_slug: str, dest_map: dict):
    """
    dataset_slug: e.g., 'nikdavis/steam-store-games'
    dest_map: {'expected_file_name_in_zip.csv': 'data/target_name.csv'}
    """
    tmp = f"_tmp_{dataset_slug.split('/')[-1]}"
    os.makedirs(tmp, exist_ok=True)

    api.dataset_download_files(dataset_slug, path=tmp, unzip=True)

    for expected_name, out_path in dest_map.items():
        found = None
        for fname in os.listdir(tmp):
            if fname.lower() == expected_name.lower():
                found = os.path.join(tmp, fname)
                break
        if not found:
            raise FileNotFoundError(
                f"Could not find '{expected_name}' in {tmp}. "
                f"Available: {sorted(os.listdir(tmp))[:10]}"
            )
        shutil.copyfile(found, out_path)

    # 
    shutil.rmtree(tmp, ignore_errors=True)

fetch_kaggle_dataset(
    "nikdavis/steam-store-games",
    dest_map={"steam.csv": "data/steam.csv"}
)

fetch_kaggle_dataset(
    "gregorut/videogamesales",
    dest_map={"vgsales.csv": "data/vgsales.csv"}
)

steam = pd.read_csv("data/steam.csv")
sales = pd.read_csv("data/vgsales.csv")
# Out:
# Dataset URL: https://www.kaggle.com/datasets/nikdavis/steam-store-games
# Dataset URL: https://www.kaggle.com/datasets/gregorut/videogamesales

# %%
print("steam.csv shape:", steam.shape)
print("vgsales.csv shape:", sales.shape)
print("steam columns (first 15):", list(steam.columns)[:15])
print("vgsales columns:", list(sales.columns))
# Out:
# steam.csv shape: (27075, 18)
# vgsales.csv shape: (16598, 11)
# steam columns (first 15): ['appid', 'name', 'release_date', 'english', 'developer', 'publisher', 'platforms', 'required_age', 'categories', 'genres', 'steamspy_tags', 'achievements', 'positive_ratings', 'negative_ratings', 'average_playtime']
# vgsales columns: ['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales']
